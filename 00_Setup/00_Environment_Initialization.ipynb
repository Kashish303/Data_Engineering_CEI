# %% [markdown]
# # Retailmart Lakehouse Project
#
# ## Notebook 00_Environment_Initialization
#
# ### Objective:
# This notebook initialize the RetailMart lakehouse Environment
#
# It performs the following tasks:
#
# - Verify Spark Session
# - Verify Python Environment
# - Verify Delta Lake Support
# - Verify Unity Catalog Access
# - Create Project Catalog (in need)
# - Create Bronze, Silver and Gold Schemas
# - Validate Workspace Configuration
#
# ### Project
# RetailMart Lakehouse using Medallion Architecture

# %%
# Retailmart lakehouse 
# Environment Initialization

print('RetailMart Lakehouse - Environment Initialization')
# Out:
# RetailMart Lakehouse - Environment Initialization

# %%
# Importing libraries
import sys
import platform 
from datetime import datetime

from pyspark.sql import SparkSession

# %%
# Environment Report 
print('Execution Time:',datetime.now())
print('Python Version:',sys.version)
print('Platform:',platform.platform())
print('Spark Version:',spark.version)
# Out:
# Execution Time: 2026-07-11 18:26:07.377749
# Python Version: 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]
# Platform: Linux-6.1.172-216.329.amzn2023.aarch64-aarch64-with-glibc2.39
# Spark Version: 4.1.0

# %%
if spark:
    print("Spark Session : Active")
else:
    print("Spark Session : Not Active")
# Out:
# Spark Session : Active

# %%
# Verify unity catalog
spark.sql("SHOW CATALOGS").show(truncate=False)
# Out:
# +---------+
# |catalog  |
# +---------+
# |dbacademy|
# |samples  |
# |system   |
# |workspace|
# +---------+

# %%
try:
    spark.sql("""
        CREATE CATALOG IF NOT EXISTS retailmart
    """)
    print("Catalog 'retailmart' created successfully.")
except Exception as e:
    print("Could not create catalog.")
    print(e)
# Out:
# Catalog 'retailmart' created successfully.

# %%
CATALOG = "retailmart"

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.bronze")

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.silver")

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.gold")
# Out:
# DataFrame[]

# %%
spark.sql(f"SHOW SCHEMAS IN {CATALOG}").show(truncate=False)
# Out:
# +------------------+
# |databaseName      |
# +------------------+
# |bronze            |
# |default           |
# |gold              |
# |information_schema|
# |silver            |
# +------------------+

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.metadata")
# Out:
# DataFrame[]

# %%
spark.sql(f"SHOW SCHEMAS IN {CATALOG}").show(truncate=False)
# Out:
# +------------------+
# |databaseName      |
# +------------------+
# |bronze            |
# |default           |
# |gold              |
# |information_schema|
# |metadata          |
# |silver            |
# +------------------+

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS retailmart.quarantine;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
