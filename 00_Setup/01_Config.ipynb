# %%
# Project Information

PROJECT_NAME = "RetailMart Lakehouse"
VERSION = "1.0"
PIPELINE = "RetailMart ETL Pipeline"

# %%
# Catalog

CATALOG = "retailmart"
BRONZE = "bronze"
SILVER = "silver"
GOLD = "gold"
METADATA = "metadata"

# %%
# Table Names

CUSTOMERS = "customers"
ORDERS = "orders"
ORDER_ITEMS = "order_items"
PRODUCTS = "products"
PAYMENTS = "payments"

# %%
# Bronze Tables

BRONZE_CUSTOMERS = f"{CATALOG}.{BRONZE}.customers"
BRONZE_ORDERS = f"{CATALOG}.{BRONZE}.orders"
BRONZE_PRODUCTS = f"{CATALOG}.{BRONZE}.products"
BRONZE_ORDER_ITEMS = f"{CATALOG}.{BRONZE}.order_items"
BRONZE_PAYMENTS = f"{CATALOG}.{BRONZE}.payments"

# %%
RAW_CUSTOMERS = "/Volumes/dbacademy/default/raw/raw_customers_dataset.csv"
TARGET_TABLE = "retailmart.bronze.customers"

# %%
RAW_ORDERS = "/Volumes/dbacademy/default/raw/raw_orders_dataset.csv"
TARGET_TABLE_ORDERS = "retailmart.bronze.orders"

# %%
RAW_ITEMS = "/Volumes/dbacademy/default/raw/raw_items_dataset.csv"
TARGET_TABLE_ITEM = "retailmart.bronze.order_items"

# %%
RAW_PAYMENTS = "/Volumes/dbacademy/default/raw/raw_payments_dataset.csv"
TARGET_TABLE_PAYMENTS = "retailmart.bronze.payments"

# %%
RAW_PRODUCTS = "/Volumes/dbacademy/default/raw/raw_products_dataset.csv"
TARGET_TABLE_PRODUCTS = "retailmart.bronze.products"

# %%
# Silver Tables

SILVER_CUSTOMERS   = f"{CATALOG}.{SILVER}.customers"
SILVER_ORDERS      = f"{CATALOG}.{SILVER}.orders"
SILVER_ORDER_ITEMS = f"{CATALOG}.{SILVER}.order_items"
SILVER_PAYMENTS    = f"{CATALOG}.{SILVER}.payments"
SILVER_PRODUCTS    = f"{CATALOG}.{SILVER}.products"

# %%
SILVER_CUSTOMER = "retailmart.silver.customers"

# %%
# Quarantine Schema

QUARANTINE_SCHEMA = "quarantine"

# %%
# Quarantine Tables

QUARANTINE_CUSTOMERS   = f"{CATALOG}.{QUARANTINE_SCHEMA}.customers"
QUARANTINE_ORDERS      = f"{CATALOG}.{QUARANTINE_SCHEMA}.orders"
QUARANTINE_ORDER_ITEMS = f"{CATALOG}.{QUARANTINE_SCHEMA}.order_items"
QUARANTINE_PAYMENTS    = f"{CATALOG}.{QUARANTINE_SCHEMA}.payments"
QUARANTINE_PRODUCTS    = f"{CATALOG}.{QUARANTINE_SCHEMA}.products"

# %%
SILVER_ORDERS =  "retailmart.silver.orders"

# %%
SILVER_ITEMS = "retailmart.silver.items"

# %%
SILVER_PRODUCTS = "retailmart.silver.products"

# %%
SILVER_PAYMENTS = "retailmart.silver.payments"

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS retailmart.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
GOLD_FACT_SALES = "retailmart.gold.fact_sales"

# %%
GOLD_MONTHLY_REVENUE = "retailmart.gold.monthly_revenue"

# %%
GOLD_CUSTOMER_360 = "retailmart.gold.customer_360"

# %%
GOLD_CUSTOMER_SEGMENTATION = "retailmart.gold.customer_segmentation"

# %%
GOLD_ABOVE_AVERAGE_CUSTOMERS = "retailmart.gold.above_average_customers"

# %%
GOLD_FUNNEL_ANALYSIS = "retailmart.gold.funnel_analysis"

# %%
GOLD_PRODUCT_RANKING = "retailmart.gold.product_ranking"

# %%
GOLD_CUSTOMER_CHURN = "retailmart.gold.customer_churn"

# %%
GOLD_TRENDING_PRODUCT = "retailmart.gold.trending_product"
